# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886     True
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
df.duplicated().sum
# Out:
# <bound method Series.sum of 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886     True
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool>

# %%
df.drop_duplicates()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 888         0       3  female   NaN      1      2  23.4500        S  Third
# 889         1       1    male  26.0      0      0  30.0000        C  First
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.reset_index()
# Out:
#      index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0        0         0       3    male  22.0      1      0   7.2500        S
# 1        1         1       1  female  38.0      1      0  71.2833        C
# 2        2         1       3  female  26.0      0      0   7.9250        S
# 3        3         1       1  female  35.0      1      0  53.1000        S
# 4        4         0       3    male  35.0      0      0   8.0500        S
# ..     ...       ...     ...     ...   ...    ...    ...      ...      ...
# 779    885         0       3  female  39.0      0      5  29.1250        Q
# 780    887         1       1  female  19.0      0      0  30.0000        S
# 781    888         0       3  female   NaN      1      2  23.4500        S
# 782    889         1       1    male  26.0      0      0  30.0000        C
# 783    890         0       3    male  32.0      0      0   7.7500        Q
#
#      class    who  adult_male deck  embark_town alive  alone
# ...

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#      index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0        0         0       3    male  22.0      1      0   7.2500        S
# 1        1         1       1  female  38.0      1      0  71.2833        C
# 2        2         1       3  female  26.0      0      0   7.9250        S
# 3        3         1       1  female  35.0      1      0  53.1000        S
# 4        4         0       3    male  35.0      0      0   8.0500        S
# ..     ...       ...     ...     ...   ...    ...    ...      ...      ...
# 779    885         0       3  female  39.0      0      5  29.1250        Q
# 780    887         1       1  female  19.0      0      0  30.0000        S
# 781    888         0       3  female   NaN      1      2  23.4500        S
# 782    889         1       1    male  26.0      0      0  30.0000        C
# 783    890         0       3    male  32.0      0      0   7.7500        Q
#
#      class    who  adult_male deck  embark_town alive  alone
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=784, step=1)

# %%
df.shape
# Out:
# (784, 16)

# %%
df.isnull().sum()
# Out:
# index            0
# survived         0
# pclass           0
# sex              0
# age            106
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           582
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
sns.heatmap(df.isnull())
plt.show()

# %%
df[df.isnull()==True].index
# Out:
# RangeIndex(start=0, stop=784, step=1)

# %%
df.dropna()
# Out:
#      index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 1        1         1       1  female  38.0      1      0  71.2833        C
# 3        3         1       1  female  35.0      1      0  53.1000        S
# 6        6         0       1    male  54.0      0      0  51.8625        S
# 10      10         1       3  female   4.0      1      1  16.7000        S
# 11      11         1       1  female  58.0      0      0  26.5500        S
# ..     ...       ...     ...     ...   ...    ...    ...      ...      ...
# 768    871         1       1  female  47.0      1      1  52.5542        S
# 769    872         0       1    male  33.0      0      0   5.0000        S
# 774    879         1       1  female  56.0      0      1  83.1583        C
# 780    887         1       1  female  19.0      0      0  30.0000        S
# 782    889         1       1    male  26.0      0      0  30.0000        C
#
#      class    who  adult_male deck  embark_town alive  alone
# ...

# %%
((784-181)/784)*100
# Out:
# 76.91326530612244

# %%
df.drop('deck',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['index', 'survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone'],
#       dtype='object')

# %%
df.dtypes
# Out:
# index             int64
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df['embark_town'].unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown', nan], dtype=object)

# %%
df['embark_town'].mode()[0]
# Out:
# 'Southampton'

# %%
df['embark_town'].isnull().sum()
# Out:
# 2

# %%
#filling missing positions

df['embark_town'].fillna('southamption')
# Out:
# 0      Southampton
# 1        Cherbourg
# 2      Southampton
# 3      Southampton
# 4      Southampton
#           ...
# 779     Queenstown
# 780    Southampton
# 781    Southampton
# 782      Cherbourg
# 783     Queenstown
# Name: embark_town, Length: 784, dtype: object

# %%
df['embark_town'].fillna(df['embark_town'].mode()[0],inplace=True)

# %%
df
# Out:
#      index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0        0         0       3    male  22.0      1      0   7.2500        S
# 1        1         1       1  female  38.0      1      0  71.2833        C
# 2        2         1       3  female  26.0      0      0   7.9250        S
# 3        3         1       1  female  35.0      1      0  53.1000        S
# 4        4         0       3    male  35.0      0      0   8.0500        S
# ..     ...       ...     ...     ...   ...    ...    ...      ...      ...
# 779    885         0       3  female  39.0      0      5  29.1250        Q
# 780    887         1       1  female  19.0      0      0  30.0000        S
# 781    888         0       3  female   NaN      1      2  23.4500        S
# 782    889         1       1    male  26.0      0      0  30.0000        C
# 783    890         0       3    male  32.0      0      0   7.7500        Q
#
#      class    who  adult_male  embark_town alive  alone
# ...

# %%
df['age'].isnull().sum()
# Out:
# 106

# %%
df['age'].median()
# Out:
# 28.25

# %%
df['age'].fillna(df['age'].median(),inplace=True)

# %%
df
# Out:
#      index  survived  pclass     sex    age  sibsp  parch     fare embarked  \
# 0        0         0       3    male  22.00      1      0   7.2500        S
# 1        1         1       1  female  38.00      1      0  71.2833        C
# 2        2         1       3  female  26.00      0      0   7.9250        S
# 3        3         1       1  female  35.00      1      0  53.1000        S
# 4        4         0       3    male  35.00      0      0   8.0500        S
# ..     ...       ...     ...     ...    ...    ...    ...      ...      ...
# 779    885         0       3  female  39.00      0      5  29.1250        Q
# 780    887         1       1  female  19.00      0      0  30.0000        S
# 781    888         0       3  female  28.25      1      2  23.4500        S
# 782    889         1       1    male  26.00      0      0  30.0000        C
# 783    890         0       3    male  32.00      0      0   7.7500        Q
#
#      class    who  adult_male  embark_town alive  alone
# ...

# %%
print('Missing values before imputation -',df['embarked'].isnull().sum())
df['embarked'].fillna(df['embarked'].mode()[0],inplace=True)
print('Missing value After imputation - ',df['embarked'].isnull().sum())
# Out:
# Missing values before imputation - 0
# Missing value After imputation -  0

# %%
df.descr\ib
